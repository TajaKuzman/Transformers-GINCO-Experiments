# %%
import os
import parse
import fasttext
import numpy as np
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
datadir = "/home/peterr/macocu/task5_webgenres/data/final/fasttext1"


def parse_test_file(path: str):
    """Reads fasttext formatted file and returns labels, texts."""
    with open(path, "r") as f:
        content = f.readlines()
    pattern = "{label} {text}\n"
    p = parse.compile(pattern)

    labels, texts = list(), list()
    for line in content:
        rez = p.parse(line)
        if rez is not None:
            labels.append(rez["label"])
            texts.append(rez["text"])
        else:
            print("error parsing line ", line)
    return labels, texts

def prediction_to_label(prediction):
    """Transforms predicitons as returned by fasttext into pure labels."""
    import numpy as np
    return np.array(prediction[0])[:, 0]

def plot_cm(y_true, y_pred, labels, save=False, title=None):
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import f1_score
    import matplotlib.pyplot as plt
    cm = confusion_matrix(y_true, y_pred, labels=labels, )
    plt.figure(figsize=(9, 9))
    plt.imshow(cm, cmap="Oranges")
    classNames = labels
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    tick_marks = np.arange(len(classNames))
    plt.xticks(tick_marks, classNames, rotation=90)
    plt.yticks(tick_marks, classNames)
    microF1 = f1_score(y_true, y_pred, labels=labels, average ="micro")
    macroF1 = f1_score(y_true, y_pred, labels=labels, average ="macro")

    print(f"{microF1=:0.4}")
    print(f"{macroF1=:0.4}")

    metrics = f"{microF1=:0.4}, {macroF1=:0.4}"
    if title:
        plt.title(title +";\n" + metrics)
    else:
        plt.title(metrics)
    plt.tight_layout()
    if save:
        plt.savefig(save)
    plt.show()
    return microF1, macroF1


all_labels = [
 '__label__Promotion_of_Services',
 '__label__Instruction',
 '__label__Review',
 '__label__Information/Explanation',
 '__label__Promotion_of_a_Product',
 '__label__News/Reporting',
 '__label__Promotion',
 '__label__Announcement',
 '__label__Invitation',
 '__label__Opinion/Argumentation',
 '__label__Forum',
 '__label__Legal/Regulation',
 '__label__Other',
 '__label__Opinionated_News',
 '__label__Call',
 '__label__List_of_Summaries/Excerpts']
len(all_labels)
# Out:
# 16

# %%
dev_full = os.path.join(datadir, "dev_onlykeep_False_onlyprimary_True_dedup_False.fasttext")
test_full = os.path.join(datadir, "test_onlykeep_False_onlyprimary_True_dedup_False.fasttext")
train_full = os.path.join(datadir, "train_onlykeep_False_onlyprimary_True_dedup_False.fasttext")

model_dir = "/home/peterr/macocu/task5_webgenres/data/models/experiment1"
micros, macros = list(), list()
for i in range(10):
    model = fasttext.train_supervised(input=train_full, 
                                            #autotuneValidationFile=dev_full, 
                                            #autotuneDuration=60*15
                                            epoch=400,
                                            #dim=100,
                                            )
    y_true, texts = parse_test_file(test_full)
    y_pred = model.predict(texts)
    y_pred = prediction_to_label(y_pred)

    m, M = plot_cm(y_true, y_pred, all_labels, save=False, title=f"")

    micros.append(m)
    macros.append(M)
    print(micros, macros)
plt.hist(micros, label="Micros")
plt.hist(macros, label="Macros")
plt.legend()
plt.show()
# Out:
# microF1=0.3353
# macroF1=0.2264
# [0.3352601156069364] [0.22641369047619048]
# microF1=0.3353
# macroF1=0.2309
# [0.3352601156069364, 0.3352601156069364] [0.22641369047619048, 0.23093185550082101]
# microF1=0.3353
# macroF1=0.2259
# [0.3352601156069364, 0.3352601156069364, 0.3352601156069364] [0.22641369047619048, 0.23093185550082101, 0.22589285714285712]
# microF1=0.3353
# macroF1=0.2309
# [0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364] [0.22641369047619048, 0.23093185550082101, 0.22589285714285712, 0.23093185550082101]
# microF1=0.3353
# macroF1=0.2304
# [0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364] [0.22641369047619048, 0.23093185550082101, 0.22589285714285712, 0.23093185550082101, 0.23035714285714287]
# microF1=0.3353
# macroF1=0.227
# [0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364] [0.22641369047619048, 0.23093185550082101, 0.22589285714285712, 0.23093185550082101, 0.23035714285714287, 0.22698840311986862]
# microF1=0.3353
# macroF1=0.2264
# [0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364] [0.22641369047619048, 0.23093185550082101, 0.22589285714285712, 0.23093185550082101, 0.23035714285714287, 0.22698840311986862, 0.22641369047619048]
# microF1=0.3353
# macroF1=0.2235
# [0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364] [0.22641369047619048, 0.23093185550082101, 0.22589285714285712, 0.23093185550082101, 0.23035714285714287, 0.22698840311986862, 0.22641369047619048, 0.2235161808976464]
# microF1=0.3372
# macroF1=0.2304
# [0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3372093023255814] [0.22641369047619048, 0.23093185550082101, 0.22589285714285712, 0.23093185550082101, 0.23035714285714287, 0.22698840311986862, 0.22641369047619048, 0.2235161808976464, 0.23035714285714287]
# microF1=0.3353
# macroF1=0.2259
# [0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3352601156069364, 0.3372093023255814, 0.3352601156069364] [0.22641369047619048, 0.23093185550082101, 0.22589285714285712, 0.23093185550082101, 0.23035714285714287, 0.22698840311986862, 0.22641369047619048, 0.2235161808976464, 0.23035714285714287, 0.22589285714285712]

# %%
plt.hist(micros, label="Micros")
plt.hist(macros, label="Macros")
plt.legend()
plt.show()
